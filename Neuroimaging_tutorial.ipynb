# %% [markdown]
# <a href="https://colab.research.google.com/github/claraweber/tutorials/blob/main/Neuroimaging_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Neuroimaging Tools
#
# Clara Weber // webercl@ cbs.mpg.de
# 02 July 2025

# %% [markdown]
# In this notebook, I aim to provide a walk-through, interactive resource to introduce you to the neuroimaging tools that we (CNG lab) commonly use.   If you want to get started using your own code, please familiarize yourself with your local environment and how to set up a conda environment (linked in our Lab wiki on GitHub). For easier use, I here use a google colab notebook, but encourage you to set up notebooks e.g. in VSCodium. Also, if you have time, read into version control and GitHub.

# %% [markdown]
# > PLEASE DO NOT EDIT THIS NOTEBOOK DIRECTLY. MAKE A COPY IN YOUR LOCAL DRIVE BEFORE RUNNING ANY CODE.
# >
# You can do so by selecting File >> Save a Copy.
# If you are a CNG lab member, please coordinate your contribution to this tutorial with the author(s). Thank you!

# %% [markdown]
# ## Getting started - or 'Housekeeping'
# First, you want to mention what your script is for, what it does, and leave your name and date in docstrings.   This is usually for python scripts not notebooks, but anyways :)

# %%
"""
Introduction notebook to Neuroimaging coding
(Interactive walk-through)

author: Clara Weber
date: 02-07-2025
"""
# Out:
# '\nIntroduction notebook to Neuroimaging coding\n(Interactive walk-through)\n\nauthor: Clara Weber\ndate: 02-07-2025\n'

# %%
# !pip install numpy
# !pip install pandas
# !pip install nibabel
# !pip install nilearn
# !pip install brainspace
# !pip install brainstat
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (5.3.2)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel) (6.5.2)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from nibabel) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from nibabel) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel) (4.14.0)
# Requirement already satisfied: nilearn in /usr/local/lib/python3.11/dist-packages (0.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (1.5.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from nilearn) (5.4.0)
# Requirement already satisfied: nibabel>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (5.3.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from nilearn) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from nilearn) (24.2)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (2.2.2)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (1.6.1)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (1.15.3)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel>=5.2.0->nilearn) (6.5.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel>=5.2.0->nilearn) (4.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->nilearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->nilearn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->nilearn) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn) (2025.6.15)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.0->nilearn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nilearn) (1.17.0)
# Collecting brainspace
#   Downloading brainspace-0.1.20-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from brainspace) (2.0.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.11/dist-packages (from brainspace) (1.15.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from brainspace) (1.6.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from brainspace) (3.10.0)
# Collecting vtk<9.3.2,>=8.1.0 (from brainspace)
#   Downloading vtk-9.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (from brainspace) (5.3.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from brainspace) (11.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from brainspace) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->brainspace) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->brainspace) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->brainspace) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->brainspace) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->brainspace) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->brainspace) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->brainspace) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->brainspace) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->brainspace) (3.6.0)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel->brainspace) (6.5.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel->brainspace) (4.14.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->brainspace) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->brainspace) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->brainspace) (1.17.0)
# Downloading brainspace-0.1.20-py3-none-any.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 18.0 MB/s eta 0:00:00
# Downloading vtk-9.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (92.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 MB 9.3 MB/s eta 0:00:00
# Installing collected packages: vtk, brainspace
# Successfully installed brainspace-0.1.20 vtk-9.3.1
# Collecting brainstat
#   Downloading brainstat-0.4.2-py3-none-any.whl.metadata (4.6 kB)
# WARNING: Package 'brainstat' has an invalid Requires-Python: Invalid specifier: '>=3.7.*'
# Collecting abagen>=0.1 (from brainstat)
#   Downloading abagen-0.1.3-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: brainspace>=0.1.2 in /usr/local/lib/python3.11/dist-packages (from brainstat) (0.1.20)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from brainstat) (3.14.0)
# Collecting netneurotools (from brainstat)
#   Downloading netneurotools-0.2.5-py3-none-any.whl.metadata (6.8 kB)
# Collecting neurosynth (from brainstat)
#   Downloading neurosynth-0.3.8.tar.gz (757 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.6/757.6 kB 15.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (from brainstat) (5.3.2)
# Requirement already satisfied: nilearn>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from brainstat) (0.12.0)
# Collecting nimare (from brainstat)
#   Downloading nimare-0.5.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from brainstat) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from brainstat) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from brainstat) (1.6.1)
# Requirement already satisfied: scipy>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from brainstat) (1.15.3)
# Collecting templateflow (from brainstat)
#   Downloading templateflow-24.2.2-py3-none-any.whl.metadata (20 kB)
# Collecting trimesh (from brainstat)
#   Downloading trimesh-4.6.13-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from brainspace>=0.1.2->brainstat) (3.10.0)
# Requirement already satisfied: vtk<9.3.2,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from brainspace>=0.1.2->brainstat) (9.3.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from brainspace>=0.1.2->brainstat) (11.2.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from nilearn>=0.7.0->brainstat) (1.5.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from nilearn>=0.7.0->brainstat) (5.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from nilearn>=0.7.0->brainstat) (24.2)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.11/dist-packages (from nilearn>=0.7.0->brainstat) (2.32.3)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel->brainstat) (6.5.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel->brainstat) (4.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->brainstat) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->brainstat) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->brainstat) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->brainstat) (3.6.0)
# Collecting bctpy (from netneurotools->brainstat)
#   Downloading bctpy-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: ply in /usr/local/lib/python3.11/dist-packages (from neurosynth->brainstat) (3.11)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from neurosynth->brainstat) (1.17.0)
# Collecting biopython (from neurosynth->brainstat)
#   Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting cognitiveatlas>=0.1.11 (from nimare->brainstat)
#   Downloading cognitiveatlas-0.1.11-py3-none-any.whl.metadata (400 bytes)
# Collecting fuzzywuzzy (from nimare->brainstat)
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from nimare->brainstat) (3.1.6)
# Requirement already satisfied: numba>=0.57.0 in /usr/local/lib/python3.11/dist-packages (from nimare->brainstat) (0.60.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.11/dist-packages (from nimare->brainstat) (1.0.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from nimare->brainstat) (5.24.1)
# Collecting pymare>=0.0.8 (from nimare->brainstat)
#   Downloading PyMARE-0.0.10-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from nimare->brainstat) (6.0.2)
# Collecting ridgeplot (from nimare->brainstat)
#   Downloading ridgeplot-0.3.2-py3-none-any.whl.metadata (10 kB)
# Collecting sparse>=0.13.0 (from nimare->brainstat)
#   Downloading sparse-0.17.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: statsmodels!=0.13.2 in /usr/local/lib/python3.11/dist-packages (from nimare->brainstat) (0.14.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nimare->brainstat) (4.67.1)
# Collecting pybids>=0.15.2 (from templateflow->brainstat)
#   Downloading pybids-0.19.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->brainspace>=0.1.2->brainstat) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->brainspace>=0.1.2->brainstat) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->brainspace>=0.1.2->brainstat) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->brainspace>=0.1.2->brainstat) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->brainspace>=0.1.2->brainstat) (3.2.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.57.0->nimare->brainstat) (0.43.0)
# Collecting formulaic>=0.3 (from pybids>=0.15.2->templateflow->brainstat)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: sqlalchemy>=1.4.31 in /usr/local/lib/python3.11/dist-packages (from pybids>=0.15.2->templateflow->brainstat) (2.0.41)
# Collecting bids-validator>=1.14.7 (from pybids>=0.15.2->templateflow->brainstat)
#   Downloading bids_validator-1.14.7.post0-py3-none-any.whl.metadata (39 kB)
# Collecting num2words>=0.5.10 (from pybids>=0.15.2->templateflow->brainstat)
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.11/dist-packages (from pybids>=0.15.2->templateflow->brainstat) (8.2.1)
# Collecting universal_pathlib>=0.2.2 (from pybids>=0.15.2->templateflow->brainstat)
#   Downloading universal_pathlib-0.2.6-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: frozendict>=2.3 in /usr/local/lib/python3.11/dist-packages (from pybids>=0.15.2->templateflow->brainstat) (2.4.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from pymare>=0.0.8->nimare->brainstat) (1.13.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from pymare>=0.0.8->nimare->brainstat) (1.17.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn>=0.7.0->brainstat) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn>=0.7.0->brainstat) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn>=0.7.0->brainstat) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn>=0.7.0->brainstat) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->nimare->brainstat) (3.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->nimare->brainstat) (8.5.0)
# Collecting bidsschematools>=0.10 (from bids-validator>=1.14.7->pybids>=0.15.2->templateflow->brainstat)
#   Downloading bidsschematools-1.0.10-py3-none-any.whl.metadata (3.2 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.3->pybids>=0.15.2->templateflow->brainstat)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting docopt>=0.6.2 (from num2words>=0.5.10->pybids>=0.15.2->templateflow->brainstat)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.31->pybids>=0.15.2->templateflow->brainstat) (3.2.3)
# Requirement already satisfied: fsspec!=2024.3.1,>=2022.1.0 in /usr/local/lib/python3.11/dist-packages (from universal_pathlib>=0.2.2->pybids>=0.15.2->templateflow->brainstat) (2025.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->pymare>=0.0.8->nimare->brainstat) (1.3.0)
# Collecting acres (from bidsschematools>=0.10->bids-validator>=1.14.7->pybids>=0.15.2->templateflow->brainstat)
#   Downloading acres-0.5.0-py3-none-any.whl.metadata (6.2 kB)
# Downloading brainstat-0.4.2-py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.9/948.9 kB 38.2 MB/s eta 0:00:00
# Downloading abagen-0.1.3-py3-none-any.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 34.1 MB/s eta 0:00:00
# Downloading netneurotools-0.2.5-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 8.8 MB/s eta 0:00:00
# Downloading nimare-0.5.2-py3-none-any.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 15.1 MB/s eta 0:00:00
# Downloading templateflow-24.2.2-py3-none-any.whl (688 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.8/688.8 kB 52.6 MB/s eta 0:00:00
# Downloading trimesh-4.6.13-py3-none-any.whl (712 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 712.4/712.4 kB 34.3 MB/s eta 0:00:00
# Downloading cognitiveatlas-0.1.11-py3-none-any.whl (7.1 kB)
# Downloading pybids-0.19.0-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.6/214.6 kB 19.0 MB/s eta 0:00:00
# Downloading PyMARE-0.0.10-py3-none-any.whl (37 kB)
# Downloading sparse-0.17.0-py2.py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.4/259.4 kB 23.4 MB/s eta 0:00:00
# Downloading bctpy-0.6.1-py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.4/110.4 kB 11.8 MB/s eta 0:00:00
# Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 37.9 MB/s eta 0:00:00
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Downloading ridgeplot-0.3.2-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 kB 5.6 MB/s eta 0:00:00
# Downloading bids_validator-1.14.7.post0-py3-none-any.whl (23 kB)
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 11.3 MB/s eta 0:00:00
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 17.1 MB/s eta 0:00:00
# Downloading universal_pathlib-0.2.6-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 5.1 MB/s eta 0:00:00
# Downloading bidsschematools-1.0.10-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 14.9 MB/s eta 0:00:00
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Downloading acres-0.5.0-py3-none-any.whl (12 kB)
# Building wheels for collected packages: neurosynth, docopt
#   Building wheel for neurosynth (setup.py) ... done
#   Created wheel for neurosynth: filename=neurosynth-0.3.8-py2.py3-none-any.whl size=554060 sha256=3693f033a0a07c541ddaa972cffd8c110b01b6a6a0c0bb5e04415b30df386e67
#   Stored in directory: /root/.cache/pip/wheels/a7/40/04/2cebd3539324a664f19a2b36c86df9608ba6ce3cd3f38ae253
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=0d28a44bb755d25eedffa3d196a5d81a7ddbddb216470e9312ac4c5197e05b61
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built neurosynth docopt
# Installing collected packages: fuzzywuzzy, docopt, universal_pathlib, trimesh, num2words, interface-meta, biopython, acres, sparse, bidsschematools, bctpy, pymare, neurosynth, formulaic, cognitiveatlas, bids-validator, abagen, ridgeplot, pybids, netneurotools, templateflow, nimare, brainstat
# Successfully installed abagen-0.1.3 acres-0.5.0 bctpy-0.6.1 bids-validator-1.14.7.post0 bidsschematools-1.0.10 biopython-1.85 brainstat-0.4.2 cognitiveatlas-0.1.11 docopt-0.6.2 formulaic-1.1.1 fuzzywuzzy-0.18.0 interface-meta-1.3.0 netneurotools-0.2.5 neurosynth-0.3.8 nimare-0.5.2 num2words-0.5.14 pybids-0.19.0 pymare-0.0.10 ridgeplot-0.3.2 sparse-0.17.0 templateflow-24.2.2 trimesh-4.6.13 universal_pathlib-0.2.6

# %% [markdown]
# Now import all packages you will need

# %%
import numpy as np
import pandas as pd
import nibabel as nib
import os

# %% [markdown]
# ## Very basic python intro
# Please use the following lines to familiarize yourself with some basics. You are very encouraged to play around a bit, create a new cell and try something new!

# %%
# everything behind a hashtag is a comment and will not be compiled
# This is a comment, and i can write everything I want here :)
# Flooble glooble

# %% [markdown]
# First, we want to define a variable. A variable is like an envelope in which you can store all kinds of things, e.g. numbers (integers, floats) or words (strings). You can show /print them using print()

# %%
# Define a variable
var = 8
another_var = 'rabbit'

# show content of variable
print(var, another_var)
# Out:
# 8 rabbit

# %% [markdown]
# Print() is a function. You can recognize functions as they have brackets after them. You can also define your own functions. They need input arguments (in the brackets in the definition) and return whatever value is compiles in the function.

# %%
def my_own_function(in_number):
  out_number = in_number + 3
  return out_number

# %%
my_own_function(var)
# Out:
# 11

# %% [markdown]
# --> what would happen if you ran my_own_function() with other inputs? try it out!

# %%
# here you can code yourself:

# %% [markdown]
# Next, let's look at loops. Imagine you have three prices that are all increased by 20%, but you do not want to calculate all prices separately. Instead, you can do the following:

# %%
prices = [3.45, 6.99, 7.49] # this is a list

for p in prices: # this iterates through the list, with every single entry in the list becoming p in an interation
  new_price = p * 1.2
  print(f'{p} now costs {new_price}')
# Out:
# 3.45 now costs 4.14
# 6.99 now costs 8.388
# 7.49 now costs 8.988

# %% [markdown]
# For most data handling in neuroimaging, we need arrays. In python, the numpy library (usually imported as np) can be used to handle arrays/matrices.

# %%
# create an array of a certain size
example_array = np.zeros((20,20))

from nilearn.plotting import plot_matrix
plot_matrix(example_array, cmap = 'BuPu')

# %%
# access certain values within an array
example_array[8,5] = 10 # here i set the value in the 8th row 5th column to 10
example_array[8,15] = 10 # here i set the value in the 8th row 15th column to 10

# you can also select whole columns or rows
example_array[4,:] = 8 # here i select all values (:) in the 4th row and set it to 7

# with colons : i can specify ranges
example_array[:4,:] = 7 # here i select all between 0th and 3rd row (: = from beginning to value or from value to end) and set it to 5
example_array[13,6:16] = 10 # here i select all values in the 15th row between the 6th and 16th column

# now let's look at the new matrix
plot_matrix(example_array, cmap = 'BuPu')

# %%
# you can show the size of an array like this
print(example_array.shape)
# Out:
# (20, 20)

# %%
# sometimes you also need to know how many different values there are in your matrix
print(np.unique(example_array)) # here we expect the values 0, 5, 7, 10 based on how we defined the array
# Out:
# [ 0.  7. 10.]

# %% [markdown]
# ### Coding exercise
#
# try to give the matrix a nose!

# %%
exercise_array = np.zeros((20,20))

# this is from the previous code
exercise_array[8,5] = 10
exercise_array[8,15] = 10
exercise_array[4,:] = 8
exercise_array[:4,:] = 7
exercise_array[13,6:16] = 10

# add nose here!!



#### # plot
plot_matrix(exercise_array, cmap = 'Greens')

# %% [markdown]
# ## General visualization functions
#
# Here, i use brainspace to show you how data visualization works. You can also use other tools such as the ENIGMA toolbox. Pick your poison :)  Here is the official documentation for brainspace https://brainspace.readthedocs.io/en/latest/

# %%
from brainspace.datasets import load_conte69, load_parcellation
from brainspace.plotting import plot_hemispheres
# Out:
# /usr/local/lib/python3.11/dist-packages/brainspace/plotting/base.py:40: UserWarning: Using Panel interactively in Colab notebooks requires the jupyter_bokeh package to be installed. Install it with:
#
#     !pip install jupyter_bokeh
#
# and try again.
#   pn.extension('vtk')
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='81f1c310-9d8d-44b8-a03c-939f9104a802'>
#   <div id="d0004457-2d6a-47ff-9c45-81a845c10aee" data-root-id="81f1c310-9d8d-44b8-a03c-939f9104a802" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6156679f-aab7-4b5a-9e71-d1f2dbe6aebd":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"81f1c310-9d8d-44b8-a03c-939f9104a802"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"672db6b3-442e-49e4-a062-d4bae49672f8","attributes":{"plot_id":"81f1c310-9d8d-44b8-a03c-939f9104a802","comm_id":"9e9419031645453bb40b1fd7c733df5e","client_comm_id":"17b2470e2bc347ee9d8fc8c088d00ff4"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","defaul ...
#   var render_items = [{"docid":"6156679f-aab7-4b5a-9e71-d1f2dbe6aebd","roots":{"81f1c310-9d8d-44b8-a03c-939f9104a802":"d0004457-2d6a-47ff-9c45-81a845c10aee"},"root_ids":["81f1c310-9d8d-44b8-a03c-939f9104a802"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.vtk !== undefined) && ( root.vtk !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# this is only required for google colab, not for e.g. VSCodium

# !apt-get -qq -y install xvfb freeglut3-dev ffmpeg> /dev/null
# !pip install vtk pyvirtualdisplay

# Start virtual display
from pyvirtualdisplay import Display
display = Display(visible=0, size=(800, 200))
display.start()
import os
os.environ["DISPLAY"] = ":" + str(display.display)
# Out:
# Requirement already satisfied: vtk in /usr/local/lib/python3.11/dist-packages (9.3.1)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from vtk) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->vtk) (1.17.0)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
# load surface, here we use conte69 - alternatively, use fsa5
surf_lh, surf_rh = load_conte69()

# %% [markdown]
# Conte69 has 64984 surface points. The first 32492 correspond to the left hemisphere, the last 32492 to the right hemisphere. Conte69 is symmetric, FSA5 is not. Let's create nonsense data in this format and project onto the surface

# %%
nonsense_data = np.random.rand(64984)

plot_hemispheres(surf_lh, surf_rh, nonsense_data, # first use the surfaces you want to use and your data
                 embed_nb = True, interactive = False, # this is to make plots work in notebook
                 size = (1200,400), zoom = 1.2, # set size of display
                 color_bar = True, cmap = 'coolwarm') # show color bar and set color map

# %% [markdown]
# ### Parcellations and midline mask
# Sometimes, we want to show all data points on the cortex. But sometimes, it can be very computationally expensive to work with 70k data points. So we can also use parcellations, where cortical regions are grouped into parcels. Let's look at a common parcellation, the Schaefer 400 parcellation

# %%
# we will load a parcellation
s400 = load_parcellation('schaefer', 400, join = True)

# %%
# what does the parcellation look like?
print(np.unique(s400).shape, 'unique values \nshape of s400 is', len(s400))
# Out:
# (401,) unique values
# shape of s400 is 64984

# %% [markdown]
# As you can see, we loaded a vector that has as many entries as our surface has vertices. Every entry is a number that corresponds to one of the 400 parcels. Now look at what this parcellation looks like on the cortical surface:

# %%
plot_hemispheres(surf_lh, surf_rh, s400,
                 embed_nb = True, interactive = False,
                 size = (1200,400), zoom = 1.2,
                 color_bar = True, cmap = 'tab20c')

# %% [markdown]
# Now, we want to parcellate our data, so we want to summarize all the values in each parcel to one value. Usually, we take the mean. So let's compress our 64984 data points to 400 parcels.

# %%
from brainspace.utils.parcellation import reduce_by_labels
data_400 = reduce_by_labels(nonsense_data, s400)

print(data_400.shape) # there will be one added value as it is 400 parcels (1-400) + 0 for midline
# Out:
# (401,)

# %% [markdown]
# Now we want to plot parcellated data. To plot it, we need 64984 data points again. To reproject this to the surface, we use a mapping tool.

# %%
from brainspace.utils.parcellation import map_to_labels

data_400_mapped_to_surface = map_to_labels(data_400, s400)

plot_hemispheres(surf_lh, surf_rh, data_400_mapped_to_surface,
                 embed_nb = True, interactive = False,
                 size = (1200,400), zoom = 1.2,
                 color_bar = True, cmap = 'coolwarm')

# %% [markdown]
# You can see that data is now grouped into parcels.  Also, above in the parcellation you can see that the medial wall (where both hemispheres connect and we do not expect useful data) is parcel number 0. We can use this to 'hide' the medial wall, i.e. replace the values there with nan (non-available) / Even when we use vertex-wise data.

# %%
mask = s400 == 0 # this defines a mask that can be used to select every location where values in s400 are 0

# %% [markdown]
# double == means: we compare two values and get an output of True or False. A single = means: we define a new variable. I will use comparators in the following, then we will return to the mask

# %%
example_var = 8 # here, single = means we define something
print('Is your variable equal to seven?', example_var == 7) # test ==

# this works similar for !=, >, <
print('Is your variable not equal to seven?', example_var != 7) # test != (is not equal to)
print('Is your variable larger than seven?', example_var > 7) # test > (is larger than)
print('Is your variable smaller than seven?', example_var < 7) # test < (is smaller than)
# Out:
# Is your variable equal to seven? False
# Is your variable not equal to seven? True
# Is your variable larger than seven? True
# Is your variable smaller than seven? False

# %% [markdown]
# Now, back to the mask. Here, we applied == to a whole vector. Let's look at the output

# %%
mask
# Out:
# array([False, False, False, ..., False, False, False])

# %%
# Now we can select all values where mask == True from our random numbers vector
nonsense_data[mask] = np.nan # make mask values nan

plot_hemispheres(surf_lh, surf_rh, nonsense_data,
                 embed_nb = True, interactive = False,
                 size = (1200,400), zoom = 1.2,
                 color_bar = True, cmap = 'coolwarm',
                 nan_color = (.7,.7,.7,1)) # set color value for nan values = the selected RGB values here correspond to grey

# %% [markdown]
# There is a lot of different parcellations out there. I only intruced Schaefer here as it is a commonly used and maybe most useful one. If you want to use any other parcellation, the same system applies - you just need a vector that specifies the parcels.

# %% [markdown]
# ### Coding exercises
#
# If you want, you can test your knowledge now.
# Here is an exercise:
# Create an array that can be plotted onto the surface, where all values are 0.
# Then, set all values in the left hemisphere to 1.

# %%
# code here

your_array = ....

# %%
# plot intermediate outcome here
plot_hemispheres(surf_lh, surf_rh, your_array,
                 embed_nb=True, interactive = False,
                 size = (1200,400), zoom = 1.2,
                 color_bar = True, cmap = 'coolwarm',
                 nan_color = (.7,.7,.7.1))

# %% [markdown]
# Good job so far! Second exercise:
# We previously used the Schaefer parcellation to create a midline mask - now, i want you to hide all parcels except number 260.

# %%
# code here

your_array_masked = ....

# %%
# plot your array
plot_hemispheres(surf_lh, surf_rh, your_array_masked,
                 embed_nb=True, interactive = False,
                 size = (1200,400), zoom = 1.2,
                 color_bar = True, cmap = 'coolwarm',
                 nan_color = (.7,.7,.7.1))

# %% [markdown]
# Good job!
# Below are the solutions. Please try to solve the problems yourself - Coding is all about problem solving, so don't be discouraged and just try it out. The more mistakes you make, the more you learn :)

# %%
#@title Solution

# define array
exercise2_data = np.zeros(64984)

# make left hemisphere 1
exercise2_data[:32492] = 1
exercise2_data[mask] = np.nan

# plot intermediate
plot_hemispheres(surf_lh, surf_rh, exercise2_data,
                 embed_nb=True, interactive = False,
                 size = (600,200), zoom = 1,
                 color_bar = True, cmap = 'coolwarm',
                 nan_color = (.7,.7,.7,1))

# %%
#@title Solution part 2
# now mask schaefer parcel 260
mask_s20 = s400 != 260

exercise2_data_masked = exercise2_data.copy()

exercise2_data_masked[mask_s20] = np.nan

# plot
plot_hemispheres(surf_lh, surf_rh, exercise2_data_masked,
                 embed_nb=True, interactive = False,
                 size = (600,200), zoom = 1,
                 color_bar = True, cmap = 'coolwarm',
                 nan_color = (.7,.7,.7,1))

# %% [markdown]
# ## HPC connectivity data
#
# Unfortunately I cannot provide a walk through for this (I can't/don't want to upload actual data to an open notebook), but we will load group-wise data and do some operations on them. Here, we use functional connectivity data from the human connectome project (HCP), available via brainspace. See how to load individual data below.

# %%
from brainspace.datasets import load_group_fc

fc_matrix = load_group_fc(parcellation = 'schaefer', scale = 400) # this is already preprocessed and everything. Usually we need to do this before, but here you don"t have to worry about ir for once

# %% [markdown]
# This gives us a 400 x 400 matrix. Let's visualize this real quick.

# %%
from nilearn.plotting import plot_matrix

plot_matrix(fc_matrix, cmap = 'coolwarm')

# %% [markdown]
# Now, if we want to plot it onto the surface, we need a 64984, vector again. We already know how to bring parcellated data in 400, shape to a 64984, shape, (see map_to_labels) above. But now, we have a 400,400 (two-dimensional) data - so first, we need to bring it into one dimension. we can do this for example by creating the average. We can use np.mean to do this. If you usually use np.mean, it gives you the overall average (so just one number), but you can specify an axis so it creates the row-wise or column-wise average.

# %%
# this is what happens if we just use np.mean

print(np.mean(fc_matrix)) # we expect only one value but we need the mean for each row/column
# Out:
# 0.2088529968891225

# %%
# now create row wise average
avg_fc_s400 = np.mean(fc_matrix, axis = 0)
# add one entry at beginning for midline
avg_fc_s400 = np.insert(avg_fc_s400, 0, 0)

# and map to labels
avg_fc = map_to_labels(avg_fc_s400, s400)

# apply midline mask
avg_fc[mask] = np.nan

# then plot
plot_hemispheres(surf_lh, surf_rh, avg_fc,
                 embed_nb = True, interactive = False,
                 size = (1200,400), zoom = 1.2,
                 color_bar = True, cmap = 'coolwarm',
                 label_text = ['FC in S400'],
                 nan_color = (.7,.7,.7,1))

# %% [markdown]
# ## Gradients
#
# We just projected data onto the surface. First, we reduced its dimensionality to one dimension, then we were able to plot it.   Another way to reduce the dimensionality of data and find trajectories of organization is gradient decomposition.
#
# https://brainspace.readthedocs.io/en/latest/python_doc/auto_examples/plot_tutorial1.html#sphx-glr-python-doc-auto-examples-plot-tutorial1-py

# %% [markdown]
# ## Load individual neuroimaging data
#
# Depending on the data at hand, you will most likely have a nifti, gifti or cifti file. (E.g. ending in .func.gii). Unfortunately I cannot provide a walk through for this (I can't/don't want to upload actual data to an open notebook), but you can use the following command to load data.

# %%
# for data files
lh_map = nib.load('/path/sub-001_ses-01_hemi-L_surf-fslr32k_label_thickness.func.gii').agg_data() # obviously adapt path and subject/session
rh_map = nib.load('/path/sub-001_ses-01_hemi-R_surf-fslr32k_label_thickness.func.gii').agg_data()

# if agg_data() doesn't work, sometimes get_fdata() works depending on the filetype in question

ct_map = np.concatenate((lh_map, rh_map))

# %%
# for surface files (you will need this less often) # extract points and faces
points_l, faces_l = nib.load('/path/sub-001_ses-01_hemi-L_space-nativepro_surf-fsLR-32k_label-midthickness.surf.gii').agg_data()
points_r, faces_r = nib.load('/path/sub-001_ses-01_hemi-R_space-nativepro_surf-fsLR-32k_label-midthickness.surf.gii').agg_data()

# reconstruct surface
from brainspace.mesh.mesh_creation import build_polydata

surf_l_ind = build_polydata(points_l, faces_l)
surf_r_ind = build_polydata(points_r, faces_r)

# now you can use native surfaces just by typing them into the plot_hemispheres function --> plot_hemispheres(surf_l_ind, surf_r_ind, data ...)
